# %%
# june 19th 2024
# code quick checks

# %%
import numpy as np
import os

from natsort import natsorted

# %%
path_wd = os.getcwd()
print(path_wd)
# Out:
# /Users/4470526/Downloads/Projects/Mistic-main-resubmission/Mistic_code_live_cell_imaging_2024

# %%
FoV_path = os.path.join(path_wd + '/code/user_inputs/figures/')
#ff_list = [] # 26th Jan 2022 #rmv
#file_order = [] #8th Feb 2022

for fname in natsorted(os.listdir(FoV_path)):
    print(fname)
# Out:
# 0_FoF1_97.png
# 1_FoF1_96.png
# 2_FoF1_95.png
# 3_FoF1_91.png
# 4_FoF1_90.png
# 5_FoF1_9.png
# 6_FoF1_89.png
# 7_FoF1_87.png
# 8_FoF1_85.png
# 9_FoF1_84.png
# 10_FoF1_83.png
# 11_FoF1_82.png
# 12_FoF1_80.png
# 13_FoF1_77.png
# 14_FoF1_74.png
# 15_FoF1_73.png
# 16_FoF1_71.png
# 17_FoF1_70.png
# 18_FoF1_67.png
# 19_FoF1_64.png
# 20_FoF1_63.png
# 21_FoF1_62.png
# 22_FoF1_61.png
# 23_FoF1_60.png
# 24_FoF1_59.png
# 25_FoF1_58.png
# 26_FoF1_57.png
# 27_FoF1_56.png
# 28_FoF1_48.png
# 29_FoF1_47.png
# 30_FoF1_46.png
# 31_FoF1_45.png
# 32_FoF1_43.png
# 33_FoF1_41.png
# 34_FoF1_40.png
# 35_FoF1_39.png
# 36_FoF1_38.png
# 37_FoF1_37.png
# 38_FoF1_36.png
# 39_FoF1_33.png
# 40_FoF1_30.png
# 41_FoF1_3.png
# 42_FoF1_29.png
# 43_FoF1_28.png
# 44_FoF1_26.png
# 45_FoF1_25.png
# 46_FoF1_23.png
# 47_FoF1_22.png
# 48_FoF1_21.png
# 49_FoF1_17.png
# 50_FoF1_15.png
# 51_FoF1_13.png
# 52_FoF1_12.png
# 53_FoF1_11.png
# 54_FoF1_1.png
# 55_FoF2_99.png
# 56_FoF2_96.png
# 57_FoF2_95.png
# 58_FoF2_93.png
# ...
